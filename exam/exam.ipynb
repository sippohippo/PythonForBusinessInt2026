# %% [markdown]
# # Exam
#
# ---

# %% [markdown]
# Have this notebook open when entering the exam. Make sure you have run the two cells below before the exam.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %% [markdown]
# ---

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE
